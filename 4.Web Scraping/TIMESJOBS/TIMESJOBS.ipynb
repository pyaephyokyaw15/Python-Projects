# %% [markdown]
# # [TIMESJOBS](https://www.timesjobs.com/)

# %%
# !pip install beautifulsoup4

# %%
# !pip install lxml

# %%
# import modules
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://www.timesjobs.com/'
job = input('Job: ')
experience = input("Enter only number.\nFor all experience, only press 'enter'.\nExperience: ")
# Out:
# Job: python
# Enter only number.
# For all experience, only press 'enter'.
# Experience: 20

# %%
# generate url based on user input
# https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=&cboWorkExp1=20
url = base_url + '/candidate/job-search.html?from=submit&txtKeywords=' + job+'&cboWorkExp1='+experience

# %%
#  fetch HTML text
html_text = requests.get(url).text
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
#
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"2a67c1bd6d",applicationID:"96895452"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventL ...
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
# 		<!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7"></script>
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js"></script>
#
#
#         <link rel="canonical" href="https://www.timesjobs.com/candidate/job-search.html"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						<link rel="next" href="https://www.timesjobs.com/candidate/job-search.html?from=submit&txtKeywords=python&cboWorkExp1=20/&sequence=2&startPage=1"/>
#
#
#
#
#
#
#
#
#
# 				<title>python Jobs with 20 years experience - TimesJobs</title>
#
#
#
#
# 			<meta name="description" content="Jobs in python with 20 years experience. Search and apply jobs online at Timesjobs.com"/>
#
#
# 		<!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#         <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
#
# </head>
#   	<body>
#   		<div id="site">
#
#
# 				<!-- Header Starts -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#
# <script type="text/javascript" src='https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js' ></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div id="fb_connect_suggest" style="display: none;" class="msg notify">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img src='https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png' alt='fconnect'></a></span>
# 		<span class="big-cls cls-icn" title="Click to Hide" onclick="javascript:ack_fbconnect_cancel();"><i class="material-icons">close</i></span>
# 		<span id="fb_connect_status"></span>
# 		</div>
# 		<div id="fb_connect_success" style="display: none;" class="msg success">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
#
#
#
#
# <header class="main-header">
# <div class="top-header">
# 	<div class="ubility-wrap clearfix">
# <ul class="top-link">
#     <li><a href="https://www.timesjobs.com" class="link-active">TimesJobs</a></li>
#     <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
#     <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#     <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
#     <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
#   </ul>
#
# <ul class="top-contact">
# 	 <li><i class="material-icons">call</i>0120 6358222</li>
#     <li>
#
#        	   <span id="chat-widget" class="live-chat">Live Chat (10am to 6pm IST)</span>
#
#     </li>
# 	</ul>
# 	</div>
# 	</div>
# 	<div class="ubility-wrap logo-section clearfix">
#
#
#
#
#
#
# 		<a itemprop="url" title="TIMESJOBS" href="https://www.timesjobs.com" class="top-tj-logo">
# 			<img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" alt="TimesJobs" width="140" height="23" title="TimesJobs" itemprop="logo">
# 		</a>
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="career-affection" class="career-affection top-notifi notify-msg covid-home-page" style="display:none">
# 		<div class="career-affection-inner wrap career-effect" id="career-affection-inner ">
# 			Is your career affected by Covid-19?
# 			<a href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('Y','TJWEB');" class="yes-button">Yes</a> <a
# 				href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('N','TJWEB');" class="no-button">No</a>
# 		</div>
# 	</div>
#
#
#
#
#
#
#
#
#
#
# 			<script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
#
#
#
#
#
#
#
# 	  <ul class="main-tj-nav clearfix">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
#  <li class="notification viewnote">
# 	<a class='dropdown-button' href='#' data-activates='notifyDropdown'>
# 		<i class="material-icons left">notifications_none</i>
# 		<span id="notification_count" class="notif-count-new">1</span>&nbsp;
# 	</a>
# 	<div class="nav-drop viewnoteTab dropdown-content" id='notifyDropdown'>
# 	<div class="showdiv">
# 		<div id="non_loggedin" class="notif-not-logedin" style="display:none;">
# 			<div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# 	 			<div class='notif-act clearfix'>
#
#
#
# 						<button type='button' class='waves-effect waves-light btn red-bdr-btn' onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</button>
#
#
# 				<strong class='or'>or</strong>
# 				<a href="/candidate/register.html" class='waves-effect waves-light btn red-bdr-btn' >Register</a>
# 	    	</div>
# 	   	</div>
#
#
#
# 		<!-- INLINE LOGIN PAGE -->
#
# 		<div id="inline_login" class="notif-login-frm" style="display:none;">
#         <span class="notif-cls" title="Click to Hide"></span>
#
#
#
# 			  <strong>Login to View Notifications!</strong>
#
#
# 		<form action="/candidate/times_login?BeforeLoginUrl=notification&tab=1" method="post" name="loginFormNotification">
#
#
#
#
# 				    <input name="j_username" id="txtUseNameNotification" type="text" onblur="javascript:settextNotification('txtUseNameNotification');" onClick="filltxtNotification(txtUseNameNotification)" value="Enter Email id / Login id" class="txt2 defaultValue inpt-typ" size="42" />
#
#
# 		    <input name="j_password" type="password" value="" class="password_input_notification" size="42"  style="display:none" />
#             <input type="text" value="Enter Password" class="clearNotification" size="42" />
#             <div class="frgt-pass"><a href="javascript:forgotPasswordNotification();" class="fp">Forgot Password?</a></div>
#
# 	      <input class="" type="submit" onClick="javascript:return validateLoginFormNotification();" value="Login" />
#
#           <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#            	      <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#                   <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
#
#   	    <input type="hidden" name="notlogin" value="mytj">
# 		  <input type="hidden" name="_acegi_security_remember_me" value="yes">
# 	    </form>
# 	    </div>
#
# 		<!-- INLINE LOGIN PAGE -->
#                        <div id="base" style="display: none;" class="notif-main">
# 						   <ul>
# 	                       	   <li id="heading" class="heading clearfix">
# 	                       	   	<a id="heading-link" href="#"><span>Job Alerts(10)</span></a>
# 	                       	   </li>
# 		                       		<li id="base-li" style="display: none;"><a id="base-li-anchor" href="#">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# 		                       		</li>
# 		                       		<span id="base-li-data" style="display: none;"  class="base_li"></span>
# 		                       </ul>
#                        </div>
#                        </div>
#           </div>
# 	  	  </li>
#
#                     <!--- view notification section ends here --->
#
#
# 	<script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1626961605-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
#
#
#
#
#
#
#
#
#
# 				<li class="login-reg">
# 					<a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# 				</li>
#
#
# 		<li class="login-reg">
#
# 				<a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
#
#
# 		</li>
#
# 	</ul>
#
#
# 	</div>
# </header>
# 	<!--bottom banner starts-->
#
#           <!--bottom banner ends-->
#
#
#
#
#
# 			<div class="open-search ">
#
#
#
#
#
#
# <div class="usability-srch clearfix">
#   <div class="main-srch-form clearfix">
# 	  <div id="errorMsgDiv" class="msg error" style="display:none">Please provide inputs for at least one field</div>
#        <form id="quickSearchBean" name="quickSearchBean" action="https://www.timesjobs.com/candidate/job-search.html" method="get"  onSubmit="return searchEngine.validateSearchForm(this);" >
#
#           	<input name="searchType" value="personalizedSearch" type="hidden">
#           	<input name="from" value="submit" type="hidden">
#           	<div class="auto-suggest-blk">
#
#
#
#
#             <input id="txtKeywords" name="txtKeywords" type="text"  value="python" class="browser-default"/>
#             <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestList" frameborder="0" style="display:none;"></iframe>
#             <div id="autoSuggestList2ndKeywordsListSFB" class="suggestionList srch-suggest" style="display:none;">
#               <h5>Suggested Keywords</h5>
#           <ul></ul></div>
#           </div>
#         <div class="auto-suggest-blk location-srch">
#
#
#   <input id="txtLocation" name="txtLocation" type="text" class="location-srch browser-default" value="Enter Location"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe id="FrameautoSuggestLocation" style="display:none" frameborder="0"></iframe></div>
#       <div class="srch-select">
#           <select id = "cboWorkExp1" name="cboWorkExp1" class="browser-default">
#
#
#
#                       <option value="-1" >Experience</option>
#
#
#
#                       <option value="0" >Entry Level</option>
#
#
#
#                       <option value="1" >1 year</option>
#
#
#
#                       <option value="2" >2 years</option>
#
#
#
#                       <option value="3" >3 years</option>
#
#
#
#                       <option value="4" >4 years</option>
#
#
#
#                       <option value="5" >5 years</option>
#
#
#
#                       <option value="6" >6 years</option>
#
#
#
#                       <option value="7" >7 years</option>
#
#
#
#                       <option value="8" >8 years</option>
#
#
#
#                       <option value="9" >9 years</option>
#
#
#
#                       <option value="10" >10 years</option>
#
#
#
#                       <option value="11" >11 years</option>
#
#
#
#                       <option value="12" >12 years</option>
#
#
#
#                       <option value="13" >13 years</option>
#
#
#
#                       <option value="14" >14 years</option>
#
#
#
#                       <option value="15" >15 years</option>
#
#
#
#                       <option value="16" >16 years</option>
#
#
#
#                       <option value="17" >17 years</option>
#
#
#
#                       <option value="18" >18 years</option>
#
#
#
#                       <option value="19" >19 years</option>
#
#
#
#
#
#                       <option value="20" selected='selected'>20 years</option>
#
#
#
#                       <option value="21" >20+ years</option>
#
#           </select>
#       </div>
#           <button class="waves-effect waves-light btn" value="Search" onclick="javascript:setAClickOnSearch();">Find Jobs</button>
#
#       </form>
#   </div>
# <div id="recentSearchId" class="recent-srchs home-srchptext srch-top-right" style="display: none;"></div>
#
#   <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#     <div class="upload-res-txt clearfix">
#       <span class="upload-icon"></span>
#       <div class="upload-res-input">
#         <h5>New to Timesjobs?</h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input name="resumeFile_basic" id="resumeFile_basic" size="25" type="file" />
#           </label>
#         <span id="uploadingResume_basic" style="display:none"><img src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif" alt="Uploading Resume"></span>
#         </div>
#       </div>
#   </div>
#
#    </div>
# <script type="text/javascript">
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# 			</div>
#
#
#
#
#
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
#
#
# <script type='text/javascript'>
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
#
#
# <script type='text/javascript'>
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
#
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
#
# 				<!-- Header Ends -->
#
# 				<!-- Content Starts   -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#
# 	<!--Cluster related page inclusion end here-->
#   <section class="ubility-lhs clearfix">
#
# <div id="search-result-cluster" class="inside-lhs">
# 	<div class="wht-bdr-bx tj-cluster">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <h4><i class="material-icons">sort</i>Refined By</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
#
#
#
#
#
#
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#
#   <div id="tj-tab-container-clusterId">
#     <div id="clusterDataInitial">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<ul class="collapsible" data-collapsible="expandable">
#
#
#   <li id="tabtc">
#
#
# 	  <div class="collapsible-header active"><h6>Companies</h6></div>
#     <div class="cluster-scroll collapsible-body">
#       <ul>
#         <div id="comp_show">
#
#
#
#
#             <li>
#
#
#
#
#
#
#
#                 <input id="com_0" type="checkbox" name="topCompanies"   onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&luceneResultSize=25&postWeek=60&txtKeywords=python&cboWorkExp1=20&undokey=compCluster&compCluster=analytics+vidhya&gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&refineBy=dateWise&from=undo&actualTxtKeywords=python&searchBy=0&rdoOperator=OR&luceneResultSize=25&postWeek=60&txtKeywords=python&cboWorkExp1=20&undokey=compCluster&compCluster=analytics+vidhya&gadLink=View Jobs By This Company','Analytics Vidhya');">
# 				<label for="com_0">
#                 <span title="Analytics Vidhya">
#                 Analytics Vidhya
#                 </span> <span class="grey-text">(6)</span></label>
#             </li>
#
#
#
#             <li>
#
#
#
#
#
#
#
# ...
#
#
#
#
# <!-- New google pixel by sokrati -->
# <!-- Global site tag (gtag.js) - Google Ads: 1067146772 -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
# </script>
#
# <!-- New google pixel by sokrati -->
#
#
#
#
# <script>
# 	var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
# </script>
#
#
# <script type="text/javascript" src="//connect.facebook.net/en_US/sdk.js"></script>
#
#
#
# 	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7"></script>
#
#
#
#
#
#
#
#
#
#
# <!-- Columbia AdTech(TIL) Code start Here -->
# <script type='text/javascript'>
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <!-- Columbia AdTech(TIL) Code end Here -->
#
# <script type='text/javascript'>
# 	function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" width="1" style="display:none"
# src="https://www.facebook.com/tr?id=1727549374127582&ev=PageView&noscript=1"
# /></noscript>
# <!-- End Facebook Pixel Code -->
# 				<!-- Footer Ends   -->
#
#
#
#
#
# 	<script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
#
#
# 	<link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" rel="stylesheet" type="text/css" media="all"/>
#
# 		<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7"></script>
#
#
#
#
# 		<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
#           <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#
#
# <script type='text/javascript'>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
#
# <noscript>
#   <img src="https://sb.scorecardresearch.com/p?c1=2&c2=6036484&cv=2.0&cj=1" />
# </noscript>
#
# <script type='text/javascript'>
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
#
# <script type='text/javascript'>
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# 	<script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
#
#
#
#
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# 	<!--Common Template Included in all files end here  -->
# 	<!--google analytics start-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# 	<!--google analytics ends-->
#
# 		<img src="https://tracking.sokrati.com/site?client_id=60&product_category=Site_Search" height="1" width="1" border="0" alt="" />
#
#
# <script type='text/javascript'>
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# 		</div>
#
# <script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js"></script>
# <div id="light-box-popup" class="modal">
# 	<span class="material-icons close-modal modal-action modal-close">close</span>
# 	<div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<!--  ##########################  JobBuzz Ads  ################## -->
#
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"applicationID":"96895452","applicationTime":340,"beacon":"bam-cell.nr-data.net","queueTime":0,"licenseKey":"2a67c1bd6d","transactionName":"NgdTbUEHV0JYBUZYWQ9Ne2pjSW50e0t7f3BOCEJJHBNKUFsPXlhCGE1FXF4WVVBNAx1SVw8GWF1SElxiXAdAUl4TB0JMXxJtVFQWXlBCBExbSkM=","agent":"","errorBeacon":"bam-cell.nr-data.net"}</script></body>
# </html>

# %%
# parse HTML text
soup = BeautifulSoup(html_text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"2a67c1bd6d",applicationID:"96895452"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,version:o,match:r}},{}],7:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&docu ...
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.7" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript">
#   </script>
#   <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
#   <link href="https://www.timesjobs.com/candidate/job-search.html?from=submit&amp;txtKeywords=python&amp;cboWorkExp1=20/&amp;sequence=2&amp;startPage=1" rel="next"/>
#   <title>
#    python Jobs with 20 years experience - TimesJobs
#   </title>
#   <meta content="Jobs in python with 20 years experience. Search and apply jobs online at Timesjobs.com" name="description"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">
#   </script>
#   <script>
#    //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#   </script>
#  </head>
#  <body>
#   <div id="site">
#    <!-- Header Starts -->
#    <!-- Google Tag Manager (noscript) -->
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#    <!-- End Google Tag Manager (noscript) -->
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#    <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript">
#    </script>
#    <div class="msg notify" id="fb_connect_suggest" style="display: none;">
#     Dear Jobseeker, Find millions of jobs on single click.
#     <span id="fb_auto_connect">
#      <a href="javascript:fconnect_auto();">
#       <img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/>
#      </a>
#     </span>
#     <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide">
#      <i class="material-icons">
#       close
#      </i>
#     </span>
#     <span id="fb_connect_status">
#     </span>
#    </div>
#    <div class="msg success" id="fb_connect_success" style="display: none;">
#     Congratulations! You have been logged in via Facebook
#    </div>
#    <header class="main-header">
#     <div class="top-header">
#      <div class="ubility-wrap clearfix">
#       <ul class="top-link">
#        <li>
#         <a class="link-active" href="https://www.timesjobs.com">
#          TimesJobs
#         </a>
#        </li>
#        <li>
#         <a href="http://jobbuzz.timesjobs.com" target="_blank">
#          JobBuzz
#         </a>
#        </li>
#        <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#        <li>
#         <a href="https://ae.timesjobs.com" target="_blank">
#          Gulf Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">
#          Career Insight
#         </a>
#        </li>
#       </ul>
#       <ul class="top-contact">
#        <li>
#         <i class="material-icons">
#          call
#         </i>
#         0120 6358222
#        </li>
#        <li>
#         <span class="live-chat" id="chat-widget">
#          Live Chat (10am to 6pm IST)
#         </span>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="ubility-wrap logo-section clearfix">
#      <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
#       <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
#      </a>
#      <div class="career-affection top-notifi notify-msg covid-home-page" id="career-affection" style="display:none">
#       <div class="career-affection-inner wrap career-effect" id="career-affection-inner ">
#        Is your career affected by Covid-19?
#        <a class="yes-button" href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('Y','TJWEB');">
#         Yes
#        </a>
#        <a class="no-button" href="javascript:void(0);" onclick="profilePreview.covidAffectedProfile('N','TJWEB');">
#         No
#        </a>
#       </div>
#      </div>
#      <script type="text/javascript">
#       jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
#      </script>
#      <ul class="main-tj-nav clearfix">
#       <script type="text/javascript">
#        var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#       </script>
#       <!--- view notification section begin --->
#       <li class="notification viewnote">
#        <a class="dropdown-button" data-activates="notifyDropdown" href="#">
#         <i class="material-icons left">
#          notifications_none
#         </i>
#         <span class="notif-count-new" id="notification_count">
#          1
#         </span>
#        </a>
#        <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
#         <div class="showdiv">
#          <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
#           <div class="notif-welcm-msg clearfix">
#            To see all recommended jobs, profile views, recruiter's contacted information, updates and more...
#           </div>
#           <div class="notif-act clearfix">
#            <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">
#             Login
#            </button>
#            <strong class="or">
#             or
#            </strong>
#            <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">
#             Register
#            </a>
#           </div>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-login-frm" id="inline_login" style="display:none;">
#           <span class="notif-cls" title="Click to Hide">
#           </span>
#           <strong>
#            Login to View Notifications!
#           </strong>
#           <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
#            <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
#            <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
#            <input class="clearNotification" size="42" type="text" value="Enter Password"/>
#            <div class="frgt-pass">
#             <a class="fp" href="javascript:forgotPasswordNotification();">
#              Forgot Password?
#             </a>
#            </div>
#            <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
#            <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#             <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#             <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#             Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
#            </div>
#            <input name="notlogin" type="hidden" value="mytj"/>
#            <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
#           </form>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-main" id="base" style="display: none;">
#           <ul>
#            <li class="heading clearfix" id="heading">
#             <a href="#" id="heading-link">
#              <span>
#               Job Alerts(10)
#              </span>
#             </a>
#            </li>
#            <li id="base-li" style="display: none;">
#             <a href="#" id="base-li-anchor">
#              5 Matching Jobs
#              <span id="base-li-time">
#               3 hrs ago
#              </span>
#             </a>
#            </li>
#            <span class="base_li" id="base-li-data" style="display: none;">
#            </span>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </li>
#       <!--- view notification section ends here --->
#       <script type="text/javascript">
#        function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1626961605-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#       </script>
#       <li class="login-reg">
#        <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">
#         Login
#        </a>
#       </li>
#       <li class="login-reg">
#        <a href="/candidate/register.html?pageFlow=TJ_SEARCH">
#         Register
#        </a>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <!--bottom banner starts-->
#    <!--bottom banner ends-->
#    <div class="open-search ">
#     <div class="usability-srch clearfix">
#      <div class="main-srch-form clearfix">
#       <div class="msg error" id="errorMsgDiv" style="display:none">
#        Please provide inputs for at least one field
#       </div>
#       <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
#        <input name="searchType" type="hidden" value="personalizedSearch"/>
#        <input name="from" type="hidden" value="submit"/>
#        <div class="auto-suggest-blk">
#         <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="python"/>
#         <div id="autoSuggestList" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestList" style="display:none;">
#         </iframe>
#         <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
#          <h5>
#           Suggested Keywords
#          </h5>
#          <ul>
#          </ul>
#         </div>
#        </div>
#        <div class="auto-suggest-blk location-srch">
#         <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="Enter Location"/>
#         <div id="autoSuggestLocation" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none">
#         </iframe>
#        </div>
#        <div class="srch-select">
#         <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
#          <option value="-1">
#           Experience
#          </option>
#          <option value="0">
#           Entry Level
#          </option>
#          <option value="1">
#           1 year
#          </option>
#          <option value="2">
#           2 years
#          </option>
#          <option value="3">
#           3 years
#          </option>
#          <option value="4">
#           4 years
#          </option>
#          <option value="5">
#           5 years
#          </option>
#          <option value="6">
#           6 years
#          </option>
#          <option value="7">
#           7 years
#          </option>
#          <option value="8">
#           8 years
#          </option>
#          <option value="9">
#           9 years
#          </option>
#          <option value="10">
#           10 years
#          </option>
#          <option value="11">
#           11 years
#          </option>
#          <option value="12">
#           12 years
#          </option>
#          <option value="13">
#           13 years
#          </option>
#          <option value="14">
#           14 years
#          </option>
#          <option value="15">
#           15 years
#          </option>
#          <option value="16">
#           16 years
#          </option>
#          <option value="17">
#           17 years
#          </option>
#          <option value="18">
#           18 years
#          </option>
#          <option value="19">
#           19 years
#          </option>
#          <option selected="selected" value="20">
#           20 years
#          </option>
#          <option value="21">
#           20+ years
#          </option>
#         </select>
#        </div>
#        <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">
#         Find Jobs
#        </button>
#       </form>
#      </div>
#      <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;">
#      </div>
#      <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#       <div class="upload-res-txt clearfix">
#        <span class="upload-icon">
#        </span>
#        <div class="upload-res-input">
#         <h5>
#          New to Timesjobs?
#         </h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#          upload your resume
#          <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
#         </label>
#         <span id="uploadingResume_basic" style="display:none">
#          <img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
# 			jQuery("#txtKeywords").val(text +","+ that);
# 			jQuery("#txtKeywords").focus();
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#     </script>
#    </div>
#    <script>
#     var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
#    </script>
#    <script type="text/javascript">
#     //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#    </script>
#    <script type="text/javascript">
#     if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
#    </script>
#    <script type="text/javascript">
#     $(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
#    </script>
#    <script>
#     jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
#    </script>
#    <!-- Header Ends -->
#    <!-- Content Starts   -->
#    <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#     <!--Cluster related page inclusion end here-->
#     <section class="ubility-lhs clearfix">
#      <div class="inside-lhs" id="search-result-cluster">
#       <div class="wht-bdr-bx tj-cluster">
#        <h4>
#         <i class="material-icons">
#          sort
#         </i>
#         Refined By
#        </h4>
#        <!--  <div id="clusterRefineHistoryId"></div>-->
#        <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#        <div id="tj-tab-container-clusterId">
#         <div id="clusterDataInitial">
#          <ul class="collapsible" data-collapsible="expandable">
#           <li id="tabtc">
#            <div class="collapsible-header active">
#             <h6>
#              Companies
#             </h6>
#            </div>
#            <div class="cluster-scroll collapsible-body">
#             <ul>
#              <div id="comp_show">
#               <li>
#                <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=20&amp;undokey=compCluster&amp;compCluster=analytics+vidhya&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=20&amp;undokey=compCluster&amp;compCluster=analytics+vidhya&amp;gadLink=View Jobs By This Company','Analytics Vidhya');" type="checkbox"/>
#                <label for="com_0">
#                 <span title="Analytics Vidhya">
#                  Analytics Vidhya
#                 </span>
#                 <span class="grey-text">
#                  (6)
#                 </span>
#                </label>
#               </li>
#               <li>
#                <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=20&amp;undokey=compCluster&amp;compCluster=cloudthat+technologies&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;actualTxtKeywords=python&amp;searchBy=0&amp;rdoOperator=OR&amp;luceneResultSize=25&amp;postWeek=60&amp;txtKeywords=python&amp;cboWorkExp1=20&amp;undokey=compCluster&amp;compCluster=cloudthat+technologies&amp;gadLink=View Jobs By This Company','Cloudthat Technologies');" type="checkbox"/>
#                <label for="com_1">
#                 <span title="Cloudthat Technologies">
#                  Cloudthat Technologies
#                 </span>
#                 <span class="grey-text">
#                  (6)
#                 </span>
#                </label>
#               </li>
#               <li>
# ...
#    <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1067146772">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-1067146772');
#    </script>
#    <!-- New google pixel by sokrati -->
#    <script>
#     var parameter="";
# 	var regFlow="";
# 	var loginFlow="";
# 	var applyFlow="";
#
# 	regFlow="false";
# 	loginFlow="false";
# 	applyFlow="false";
#
# 	if(regFlow=="true")
# 	{
# 		parameter="_registrationFlow";
# 		ajaxController.trackCounter(parameter, "reg_3p9901_exp");
# 	}
# 	else if(loginFlow=="true"){
# 		var login = new RegExp("login.html", "i");
# 		if(!login.test(window.top.location) ){
# 			parameter="_loginFlow";
# 			ajaxController.trackCounter(parameter, "login_3p9901_exp");
# 		}
# 	}
#
# 	if(applyFlow=="true"){
# 		parameter="_applyFlow";
# 		ajaxController.trackCounter(parameter, "apply_3p9901_exp");
# 	}
#    </script>
#    <script src="//connect.facebook.net/en_US/sdk.js" type="text/javascript">
#    </script>
#    <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/fb_auto_connect.js?v=7.1.7" type="text/javascript">
#    </script>
#    <!-- Columbia AdTech(TIL) Code start Here -->
#    <script type="text/javascript">
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://static.clmbtech.com/ase/2320/34/aa.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#    <!-- Columbia AdTech(TIL) Code end Here -->
#    <script type="text/javascript">
#     function freshWidgetCallback(){
# 		FreshWidget.init("", {"queryString": "&widgetType=popup&captcha=yes&searchArea=no", "backgroundImage": "https://www.ceoconnect.in/feedback/images/tj_feedback.gif", "utf8": "?", "widgetType": "popup", "buttonType": "image", "buttonText": "Support", "buttonColor": "black", "buttonBg": "#b8eaff", "alignment": "2", "offset": "145px", "formHeight": "500px", "captcha": "yes", "url": "https://timesjobs.freshdesk.com"} );
# 	}
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://assets.freshdesk.com/widget/freshwidget.js';
#          var x = document.getElementsByTagName('script')[0];
#          // most browsers
# 		s.onload = freshWidgetCallback;
# 		// IE 6 & 7
# 		s.onreadystatechange = function() {
# 			if (this.readyState == 'complete') {
# 				freshWidgetCallback();
# 			}
# 		}
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#    <!-- Facebook Pixel Code -->
#    <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1727549374127582'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#    </script>
#    <noscript>
#     <img height="1" src="https://www.facebook.com/tr?id=1727549374127582&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#    </noscript>
#    <!-- End Facebook Pixel Code -->
#    <!-- Footer Ends   -->
#    <script type="text/javascript">
#     var GB_ROOT_DIR = "/candidate/greybox/";
#    </script>
#    <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
#    <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.7" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var _sf_startpt=(new Date()).getTime()
#    </script>
#    <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#    <script type="text/javascript">
#     var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#    </script>
#    <noscript>
#     <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
#    </noscript>
#    <script type="text/javascript">
#     /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
#    </script>
#    <script type="text/javascript">
#     jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
#    </script>
#    <script type="text/javascript">
#     function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
#    </script>
#    <script type="text/javascript">
#     var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
#    </script>
#    <script type="application/ld+json">
#     {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
#    </script>
#    <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
#    </script>
#    <!--Common Template Included in all files end here  -->
#    <!--google analytics start-->
#    <script type="text/javascript">
#     var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
#    </script>
#    <!--google analytics ends-->
#    <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
#    <script type="text/javascript">
#     function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
#    </script>
#   </div>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript">
#   </script>
#   <div class="modal" id="light-box-popup">
#    <span class="material-icons close-modal modal-action modal-close">
#     close
#    </span>
#    <div class="modal-content" id="light-box-popup-content">
#    </div>
#   </div>
#   <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#   <!--  ##########################  JobBuzz Ads  ################## -->
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"applicationID":"96895452","applicationTime":340,"beacon":"bam-cell.nr-data.net","queueTime":0,"licenseKey":"2a67c1bd6d","transactionName":"NgdTbUEHV0JYBUZYWQ9Ne2pjSW50e0t7f3BOCEJJHBNKUFsPXlhCGE1FXF4WVVBNAx1SVw8GWF1SElxiXAdAUl4TB0JMXxJtVFQWXlBCBExbSkM=","agent":"","errorBeacon":"bam-cell.nr-data.net"}
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Only One Job

# %%
job = soup.find('li', class_='clearfix job-bx wht-shd-bx')
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','1' )" target="_blank">
#       Hiring Full stack developer - ReactJS / NodeJS / <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# As a Full Stack Developer ,  you will work on a eCommerce project to elevate the digital experience for the mobile and web eCommerce and Personalization experiences across mul... <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  information technology  ,  html5  ,  git  ,  html  ,  <strong class="blkclor">python</strong>  ,  mobile  ,  javascript  ,  node.js
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66146007">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66146007','adId=xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>

# %%
company_name = job.find('h3', class_='joblist-comp-name')
print(company_name)
# Out:
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>

# %%
company_name = job.find('h3', class_='joblist-comp-name').text.strip()
print('Company: ',company_name)
# Out:
# Company:  glan management consultancy pvt. ltd.

# %%
skill = job.find('span', class_='srp-skills').text.strip()
print('Skill: ',skill)
# Out:
# Skill:  css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js

# %%
published_date = job.find('span', class_='sim-posted').text.strip()
print('Posted Date: ',published_date)
# Out:
# Posted Date:  Posted few days ago

# %%
published_date = job.find('span', class_='sim-posted').span.text.strip()
print('Posted Date: ',published_date)
# Out:
# Posted Date:  Posted few days ago

# %% [markdown]
# ### Jobs on Single Page

# %%
jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
print(jobs)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','1' )" target="_blank">
#       Hiring Full stack developer - ReactJS / NodeJS / <strong class="blkclor">Python</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# As a Full Stack Developer ,  you will work on a eCommerce project to elevate the digital experience for the mobile and web eCommerce and Personalization experiences across mul... <a href="https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  information technology  ,  html5  ,  git  ,  html  ,  <strong class="blkclor">python</strong>  ,  mobile  ,  javascript  ,  node.js
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66146007">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66146007','adId=xywJrj4x6sVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66146007','css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js','Mumbai','8 - 20','IT Software : Software Products &amp; Services','1')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66110871','css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication','Mumbai','7 - 20','IT Software : Software Products &amp; Services','2' )" target="_blank">
#       senior backend developer - Node.js / <strong class="blkclor">Python</strong> / AWS</a> </h2>
# <h3 class="joblist-comp-name">
#     glan management consultancy pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>7 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Description:Position: Backend Developer  ( Node.JS ,  python ,  amazon aws )  Location: Mumbai Experience: 7-20 year Salary: NegotiableRequirements : - Must have 7  years ... <a href="https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  <strong class="blkclor">python</strong>  ,  javascript  ,  node.js  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66110871">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66110871','adId=ZOII5LjoCUZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66110871','css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication','Mumbai','7 - 20','IT Software : Software Products &amp; Services','2')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-noida-greater-noida-10-to-20-yrs-jobid-AqULIx3MBpJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66906347','algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing','Noida/Greater Noida','10 - 20','IT Software : Software Products &amp; Services','3' )" target="_blank">
#       Sales Analytics and Insights lead</a> </h2>
# <h3 class="joblist-comp-name">
#     Analytics Vidhya
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>10 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Noida/Greater Noida">Noida/Greater Noida</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Our global sales transformation is in full swing. We embarked on a path of transforming and building a world class sales organization earlier this year. Our team helps to powe... <a href="https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-noida-greater-noida-10-to-20-yrs-jobid-AqULIx3MBpJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  sql  ,  san  ,  <strong class="blkclor">python</strong>  ,  machine learning  ,  swing
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Noida/Greater Noida
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66906347">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66906347','adId=AqULIx3MBpJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66906347','algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing','Noida/Greater Noida','10 - 20','IT Software : Software Products &amp; Services','3')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/principal-architect-advanced-engineering-icertis-20-to-23-yrs-jobid-YyCQroZkcUhzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67051883','security  ,  java  ,  multithreading  ,  c#  ,  python  ,  windows','','20 - 23','IT Software : Software Products &amp; Services','4' )" target="_blank">
#       Principal Architect ,  Advanced Engineering</a> </h2>
# <h3 class="joblist-comp-name">
#     ICERTIS
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>20 - 23 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title=""></span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Understand complex business problems and design product features that are secure ,  scalable ,  robust ,  and easy to implement and maintain. Evangelize and enforce best pract... <a href="https://www.timesjobs.com/job-detail/principal-architect-advanced-engineering-icertis-20-to-23-yrs-jobid-YyCQroZkcUhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           security  ,  java  ,  multithreading  ,  c#  ,  <strong class="blkclor">python</strong>  ,  windows
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67051883">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67051883','adId=YyCQroZkcUhzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67051883','security  ,  java  ,  multithreading  ,  c#  ,  python  ,  windows','','20 - 23','IT Software : Software Products &amp; Services','4')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-gurgaon-10-to-20-yrs-jobid-1ll4KhRbLqxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66735711','algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing','Gurgaon','10 - 20','IT Software : Software Products &amp; Services','5' )" target="_blank">
#       Sales Analytics and Insights lead</a> </h2>
# <h3 class="joblist-comp-name">
#     Analytics Vidhya
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>10 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Gurgaon">Gurgaon</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# 10  years of experience in analytics ,  engineering or management consulting or equivalent analytical and project management experienceAccomplished team leader ,  with experie... <a href="https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-gurgaon-10-to-20-yrs-jobid-1ll4KhRbLqxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  sql  ,  san  ,  <strong class="blkclor">python</strong>  ,  machine learning  ,  swing
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Gurgaon
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66735711">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66735711','adId=1ll4KhRbLqxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66735711','algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing','Gurgaon','10 - 20','IT Software : Software Products &amp; Services','5')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/staff-engineer-networking-cohesity-bengaluru-bangalore-10-to-20-yrs-jobid-jTvEwmtNdr5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67048115','c    ,  linux  ,  python  ,  c  ,  linux networking  ,  sdn','Bengaluru / Bangalore','10 - 20','IT Software : Software Products &amp; Services','6' )" target="_blank">
#       Staff Engineer - Networking</a> </h2>
# <h3 class="joblist-comp-name">
#     Cohesity
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>10 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Will be working as an individual contributor ,  Driving the design and implementation of Networking solutions across multiple layers of the Stack.design ,  mentor ,  implement... <a href="https://www.timesjobs.com/job-detail/staff-engineer-networking-cohesity-bengaluru-bangalore-10-to-20-yrs-jobid-jTvEwmtNdr5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  linux  ,  <strong class="blkclor">python</strong>  ,  c  ,  linux networking  ,  sdn
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67048115">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67048115','adId=jTvEwmtNdr5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67048115','c    ,  linux  ,  python  ,  c  ,  linux networking  ,  sdn','Bengaluru / Bangalore','10 - 20','IT Software : Software Products &amp; Services','6')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/lead-insights-analyst-kvc-consultants-ltd-hyderabad-secunderabad-19-to-22-yrs-jobid-ySW72VwCdq9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66990777','sql  ,  mysql  ,  python  ,  machine learning  ,  web technologies','Hyderabad/Secunderabad','19 - 22','IT Software : Software Products &amp; Services','7' )" target="_blank">
#       Lead Insights Analyst</a> </h2>
# <h3 class="joblist-comp-name">
#     KVC CONSULTANTS LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>19 - 22 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Hyderabad/Secunderabad">Hyderabad/Secunderabad</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job DescriptionGreetings we are looking for Customer Insight Analyst for an Organisation in Hyderabad.*Looking only for people with notice period 30 days or less.Job descripti... <a href="https://www.timesjobs.com/job-detail/lead-insights-analyst-kvc-consultants-ltd-hyderabad-secunderabad-19-to-22-yrs-jobid-ySW72VwCdq9zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           sql  ,  mysql  ,  <strong class="blkclor">python</strong>  ,  machine learning  ,  web technologies
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Hyderabad/Secunderabad
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66990777">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66990777','adId=ySW72VwCdq9zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66990777','sql  ,  mysql  ,  python  ,  machine learning  ,  web technologies','Hyderabad/Secunderabad','19 - 22','IT Software : Software Products &amp; Services','7')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/cloud-native-software-architect-parallel-wireless-pune-bengaluru-bangalore-18-to-21-yrs-jobid-OZyUpGpd8j9zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66915829','c    ,  docker  ,  wireless communication  ,  linux  ,  telecom  ,  python  ,  mobile  ,  infrastructure  ,  nfv','Pune,  Bengaluru / Bangalore','18 - 21','IT Software : Software Products &amp; Services','8' )" target="_blank">
#       Cloud-Native Software Architect</a> </h2>
# <h3 class="joblist-comp-name">
#     Parallel Wireless
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>18 - 21 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Bengaluru / Bangalore">Pune,  Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Job Role:Software Architect tasked with architecture ,  design and development of innovative and highly scalable cloud-native edge-cloud productsMinimum Qualifications:18  yea... <a href="https://www.timesjobs.com/job-detail/cloud-native-software-architect-parallel-wireless-pune-bengaluru-bangalore-18-to-21-yrs-jobid-OZyUpGpd8j9zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  docker  ,  wireless communication  ,  linux  ,  telecom  ,  <strong class="blkclor">python</strong>  ,  mobile  ,  infrastructure  ,  nfv
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune,  Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66915829">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66915829','adId=OZyUpGpd8j9zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66915829','c    ,  docker  ,  wireless communication  ,  linux  ,  telecom  ,  python  ,  mobile  ,  infrastructure  ,  nfv','Pune,  Bengaluru / Bangalore','18 - 21','IT Software : Software Products &amp; Services','8')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/vp-data-science-quantium-solutions-17-to-20-yrs-jobid-05hQkan__PLUS__0__SLASH__RzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66371860','scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning','','17 - 20','IT Software : Software Products &amp; Services','9' )" target="_blank">
#       VP ,  Data Science</a> </h2>
# <h3 class="joblist-comp-name">
#     QUANTIUM SOLUTIONS
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>17 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title=""></span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# See all the jobs at Quantium here:VP ,  Data ScienceSan Francisco ,  California ,  United States | Q-US | Full-timeSince 2002 ,  Quantium have combined the best of human and a... <a href="https://www.timesjobs.com/job-detail/vp-data-science-quantium-solutions-17-to-20-yrs-jobid-05hQkan__PLUS__0__SLASH__RzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           scala  ,  artificial intelligence  ,  san  ,  rest  ,  <strong class="blkclor">python</strong>  ,  machine learning
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66371860">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66371860','adId=05hQkan__PLUS__0__SLASH__RzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66371860','scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning','','17 - 20','IT Software : Software Products &amp; Services','9')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/vp-data-science-quantium-analytics-17-to-20-yrs-jobid-N5Cun1oPAWdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66371859','scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning','','17 - 20','IT Software : Software Products &amp; Services','10' )" target="_blank">
#       VP ,  Data Science</a> </h2>
# <h3 class="joblist-comp-name">
#     Quantium Analytics
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>17 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title=""></span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# See all the jobs at Quantium here:VP ,  Data ScienceSan Francisco ,  California ,  United States | Q-US | Full-timeSince 2002 ,  Quantium have combined the best of human and a... <a href="https://www.timesjobs.com/job-detail/vp-data-science-quantium-analytics-17-to-20-yrs-jobid-N5Cun1oPAWdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           scala  ,  artificial intelligence  ,  san  ,  rest  ,  <strong class="blkclor">python</strong>  ,  machine learning
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66371859">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66371859','adId=N5Cun1oPAWdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66371859','scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning','','17 - 20','IT Software : Software Products &amp; Services','10')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/cloud-development-master-greenlake-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-sUYxHcpT__SLASH__qdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67058834','compilers  ,  devops  ,  debugging  ,  middleware  ,  python  ,  machine learning  ,  infrastructure  ,  forms','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','11' )" target="_blank">
#       Cloud Development Master - Greenlake</a> </h2>
# <h3 class="joblist-comp-name">
#     HP ENTERPRISE SERVICES
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>15 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Hewlett Packard Enterprise advances the way people live and work. We bring together the brightest minds to create breakthrough technology solutions ,  helping our customers ma... <a href="https://www.timesjobs.com/job-detail/cloud-development-master-greenlake-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-sUYxHcpT__SLASH__qdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           compilers  ,  devops  ,  debugging  ,  middleware  ,  <strong class="blkclor">python</strong>  ,  machine learning  ,  infrastructure  ,  forms
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67058834">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67058834','adId=sUYxHcpT__SLASH__qdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67058834','compilers  ,  devops  ,  debugging  ,  middleware  ,  python  ,  machine learning  ,  infrastructure  ,  forms','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','11')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/cloud-application-solutions-evangelist-careerxperts-consulting-hyderabad-secunderabad-gurgaon-mumbai-bengaluru-bangalore-8-to-20-yrs-jobid-MK73__SLASH____SLASH__f6cSVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','63971201','python  ,  c    ,  solution architect  ,  java  ,  infrastructure  ,  cloud computing','Hyderabad/Secunderabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore','8 - 20','IT Software : Software Products &amp; Services','12' )" target="_blank">
#       Cloud Application Solutions Evangelist</a> </h2>
# <h3 class="joblist-comp-name">
#     CAREERXPERTS CONSULTING
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>8 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Hyderabad/Secunderabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore">Hyderabad/Secunderabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Do you like helping customers solve technical problems? Would you like to do this using the latest cloud computing technologies?Do you have a knack for helping companies under... <a href="https://www.timesjobs.com/job-detail/cloud-application-solutions-evangelist-careerxperts-consulting-hyderabad-secunderabad-gurgaon-mumbai-bengaluru-bangalore-8-to-20-yrs-jobid-MK73__SLASH____SLASH__f6cSVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">python</strong>  ,  c    ,  solution architect  ,  java  ,  infrastructure  ,  cloud computing
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Hyderabad/Secunderabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_63971201">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('63971201','adId=MK73__SLASH____SLASH__f6cSVzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','63971201','python  ,  c    ,  solution architect  ,  java  ,  infrastructure  ,  cloud computing','Hyderabad/Secunderabad,  Gurgaon,  Mumbai,  Bengaluru / Bangalore','8 - 20','IT Software : Software Products &amp; Services','12')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-data-scientist-nlu-nlp-analytics-vidhya-hyderabad-secunderabad-6-to-20-yrs-jobid-NraEhfjXXHdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66020012','algorithms  ,  python  ,  natural language processing  ,  machine learning  ,  artificial intelligence','Hyderabad/Secunderabad','6 - 20','IT Software : Software Products &amp; Services','13' )" target="_blank">
#       Senior Data Scientist NLU /  NLP</a> </h2>
# <h3 class="joblist-comp-name">
#     Analytics Vidhya
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>6 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Hyderabad/Secunderabad">Hyderabad/Secunderabad</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Details:Hands-on skills with complex Machine learning  /  Deep learning-based techniques and frameworks for optimal accuracy and performance in big production systems using Py... <a href="https://www.timesjobs.com/job-detail/senior-data-scientist-nlu-nlp-analytics-vidhya-hyderabad-secunderabad-6-to-20-yrs-jobid-NraEhfjXXHdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  <strong class="blkclor">python</strong>  ,  natural language processing  ,  machine learning  ,  artificial intelligence
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Hyderabad/Secunderabad
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66020012">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66020012','adId=NraEhfjXXHdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66020012','algorithms  ,  python  ,  natural language processing  ,  machine learning  ,  artificial intelligence','Hyderabad/Secunderabad','6 - 20','IT Software : Software Products &amp; Services','13')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-j2mJL5zgdclzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66605062','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','14' )" target="_blank">
#       Senior System Validation Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     Intel Technologies
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Senior System Validation Engineer Job DescriptionOur team needs you. We are part of the Silicon Engineering organization within the Connectivity group under DPG ,  and we are ... <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-j2mJL5zgdclzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  <strong class="blkclor">python</strong>  ,  c
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66605062">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66605062','adId=j2mJL5zgdclzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66605062','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','14')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-aVGtebNAqNJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66593819','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','15' )" target="_blank">
#       Senior System Validation Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     Intel Technologies
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Senior System Validation Engineer Job DescriptionOur team needs you We are part of the Silicon Engineering organization within the Connectivity group under DPG and we are look... <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-aVGtebNAqNJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  <strong class="blkclor">python</strong>  ,  c
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66593819">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66593819','adId=aVGtebNAqNJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66593819','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','15')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/001536.png" alt="Saama Technologies Pvt Ltd" title="Saama Technologies Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/cloud-architect-saama-technologies-pvt-ltd-pune-14-to-20-yrs-jobid-OorolNmxR3RzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66713396','security  ,  java  ,  iam  ,  software engineering  ,  cloud computing  ,  python  ,  infrastructure setup','Pune','14 - 20','IT Software : Software Products &amp; Services','16' )" target="_blank">
#       Cloud Architect</a> </h2>
# <h3 class="joblist-comp-name">
#     Saama Technologies Pvt Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>14 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune">Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Must have 14 - 20 years of professional experience specializing within open source  ( Java and / or Python )  software engineeringMust have professional experience with design... <a href="https://www.timesjobs.com/job-detail/cloud-architect-saama-technologies-pvt-ltd-pune-14-to-20-yrs-jobid-OorolNmxR3RzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           security  ,  java  ,  iam  ,  software engineering  ,  cloud computing  ,  <strong class="blkclor">python</strong>  ,  infrastructure setup
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66713396">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66713396','adId=OorolNmxR3RzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66713396','security  ,  java  ,  iam  ,  software engineering  ,  cloud computing  ,  python  ,  infrastructure setup','Pune','14 - 20','IT Software : Software Products &amp; Services','16')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/003548.gif" alt="Intel Technology India Pvt Ltd" title="Intel Technology India Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-1EBCP36v8dpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66602864','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','17' )" target="_blank">
#       Senior System Validation Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     Intel Technology India Pvt Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Senior System Validation Engineer Job DescriptionOur team needs you. We are part of the Silicon Engineering organization within the Connectivity group under DPG ,  and we are ... <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-1EBCP36v8dpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  <strong class="blkclor">python</strong>  ,  c
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66602864">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66602864','adId=1EBCP36v8dpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66602864','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','17')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/003548.gif" alt="Intel Technology India Pvt Ltd" title="Intel Technology India Pvt Ltd"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-p07jucDKZ6lzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66590825','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','18' )" target="_blank">
#       Senior System Validation Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     Intel Technology India Pvt Ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>12 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Senior System Validation Engineer Job DescriptionOur team needs you We are part of the Silicon Engineering organization within the Connectivity group under DPG and we are look... <a href="https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-p07jucDKZ6lzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  <strong class="blkclor">python</strong>  ,  c
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66590825">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66590825','adId=p07jucDKZ6lzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66590825','c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c','Bengaluru / Bangalore','12 - 20','IT Software : Software Products &amp; Services','18')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/sales-operations-analyst-i-eagleview-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-3NeTcTiEzIJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66840848','bi  ,  sql  ,  salesforce  ,  database  ,  python  ,  problem solving  ,  machine learning  ,  imaging','Bengaluru / Bangalore','17 - 20','IT Software : Software Products &amp; Services','19' )" target="_blank">
#       Sales Operations Analyst I</a> </h2>
# <h3 class="joblist-comp-name">
#     EagleView Technologies
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>17 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Mixing technology ,  data ,  and first-in-class innovation ,  EagleView is not only leading the property data analytics market ,  but also changing lives along the way. Come j... <a href="https://www.timesjobs.com/job-detail/sales-operations-analyst-i-eagleview-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-3NeTcTiEzIJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           bi  ,  sql  ,  salesforce  ,  database  ,  <strong class="blkclor">python</strong>  ,  problem solving  ,  machine learning  ,  imaging
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66840848">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66840848','adId=3NeTcTiEzIJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66840848','bi  ,  sql  ,  salesforce  ,  database  ,  python  ,  problem solving  ,  machine learning  ,  imaging','Bengaluru / Bangalore','17 - 20','IT Software : Software Products &amp; Services','19')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/technical-architect-and-product-owner-data-analytics-and-workload-solutions-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-aetJkB2aZ5hzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66820837','orchestration  ,  database  ,  apache  ,  linux  ,  debugging  ,  hadoop  ,  python  ,  oracle  ,  infrastructure','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','20' )" target="_blank">
#       Technical Architect and Product Owner  Data ,  Analytics and workload solutions</a> </h2>
# <h3 class="joblist-comp-name">
#     HP ENTERPRISE SERVICES
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>15 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# At HPE we bring together the brightest minds to create breakthrough technology solutions that advance the way people live and work. We see a future for our customers that will... <a href="https://www.timesjobs.com/job-detail/technical-architect-and-product-owner-data-analytics-and-workload-solutions-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-aetJkB2aZ5hzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           orchestration  ,  database  ,  apache  ,  linux  ,  debugging  ,  hadoop  ,  <strong class="blkclor">python</strong>  ,  oracle  ,  infrastructure
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66820837">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66820837','adId=aetJkB2aZ5hzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66820837','orchestration  ,  database  ,  apache  ,  linux  ,  debugging  ,  hadoop  ,  python  ,  oracle  ,  infrastructure','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','20')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/027496.jpg" alt="AMAZON INDIA PVT LTD" title="AMAZON INDIA PVT LTD"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/business-analyst-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-BJuIqryOjNdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67112680','hive  ,  bi  ,  data warehousing  ,  pig  ,  database  ,  hadoop  ,  big data  ,  hbase  ,  python  ,  written communication','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','21' )" target="_blank">
#       Business Analyst</a> </h2>
# <h3 class="joblist-comp-name">
#     AMAZON INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>20 - 23 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Over the past 20 years Amazon has earned the trust of over 300 million customers worldwide by providing unprecedented convenience ,  selection and value on Amazon.com. By depl... <a href="https://www.timesjobs.com/job-detail/business-analyst-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-BJuIqryOjNdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           hive  ,  bi  ,  data warehousing  ,  pig  ,  database  ,  hadoop  ,  big data  ,  hbase  ,  <strong class="blkclor">python</strong>  ,  written communication
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67112680">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67112680','adId=BJuIqryOjNdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67112680','hive  ,  bi  ,  data warehousing  ,  pig  ,  database  ,  hadoop  ,  big data  ,  hbase  ,  python  ,  written communication','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','21')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 5 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/027496.jpg" alt="AMAZON INDIA PVT LTD" title="AMAZON INDIA PVT LTD"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-gPu4O7VkkAZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67112679','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','22' )" target="_blank">
#       Software Development Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     AMAZON INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>20 - 23 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# DESCRIPTION Want to work on the coolest technology while growing your career ,  in a group that cares about people just as much as products?Amazon Pay team is looking for Soft... <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-gPu4O7VkkAZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  <strong class="blkclor">python</strong>  ,  c  ,  written communication  ,  unix
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67112679">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67112679','adId=gPu4O7VkkAZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67112679','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','22')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 5 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/027496.jpg" alt="AMAZON INDIA PVT LTD" title="AMAZON INDIA PVT LTD"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-3qDX9dUc0hBzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67105868','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','23' )" target="_blank">
#       Software Development Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     AMAZON INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>20 - 23 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# DESCRIPTION Want to work on the coolest technology while growing your career ,  in a group that cares about people just as much as products?Amazon Pay team is looking for Soft... <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-3qDX9dUc0hBzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  <strong class="blkclor">python</strong>  ,  c  ,  written communication  ,  unix
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67105868">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67105868','adId=3qDX9dUc0hBzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67105868','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','23')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 6 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/027496.jpg" alt="AMAZON INDIA PVT LTD" title="AMAZON INDIA PVT LTD"/> </span> -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-MpclfRtZ6fpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67105865','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','24' )" target="_blank">
#       Software Development Engineer</a> </h2>
# <h3 class="joblist-comp-name">
#     AMAZON INDIA PVT LTD
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>20 - 23 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# DESCRIPTION Want to work on the coolest technology while growing your career ,  in a group that cares about people just as much as products?The Amazon Pay team is looking for ... <a href="https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-MpclfRtZ6fpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  <strong class="blkclor">python</strong>  ,  c  ,  written communication  ,  unix
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67105865">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67105865','adId=MpclfRtZ6fpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67105865','algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix','Bengaluru / Bangalore','20 - 23','IT Software : Software Products &amp; Services','24')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 6 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/senior-data-architect-analytics-vidhya-bengaluru-bangalore-15-to-20-yrs-jobid-IKyhbbOHbkpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','65764170','java  ,  big data  ,  python  ,  cassandra  ,  hive  ,  data warehousing  ,  security  ,  database  ,  hadoop  ,  mongodb  ,  information management','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','25' )" target="_blank">
#       Senior Data Architect</a> </h2>
# <h3 class="joblist-comp-name">
#     Analytics Vidhya
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>15 - 20 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore">Bengaluru / Bangalore</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# If you are eager to use your creativity and results-oriented critical thinking to meet complex challenges and develop new strategies for acquiring ,  analyzing ,  modeling and... <a href="https://www.timesjobs.com/job-detail/senior-data-architect-analytics-vidhya-bengaluru-bangalore-15-to-20-yrs-jobid-IKyhbbOHbkpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           java  ,  big data  ,  <strong class="blkclor">python</strong>  ,  cassandra  ,  hive  ,  data warehousing  ,  security  ,  database  ,  hadoop  ,  mongodb  ,  information management
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_65764170">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('65764170','adId=IKyhbbOHbkpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','65764170','java  ,  big data  ,  python  ,  cassandra  ,  hive  ,  data warehousing  ,  security  ,  database  ,  hadoop  ,  mongodb  ,  information management','Bengaluru / Bangalore','15 - 20','IT Software : Software Products &amp; Services','25')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>]

# %%
for job in jobs:
    position = job.find('h2').text.strip()
    print('Position: ', position)
    company_name = job.find('h3', class_='joblist-comp-name').text.strip()
    print('Company: ',company_name)
    skill = job.find('span', class_='srp-skills').text.strip()
    print('Skill: ',skill)
    published_date = job.find('span', class_='sim-posted').span.text.strip()
    print('Posted Date: ',published_date)
    more_info = job.header.h2.a['href']
    print('More info: ', more_info)
    print('-----------------------------------------------------------------------')
# Out:
# Position:  Hiring Full stack developer - ReactJS / NodeJS / Python
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  senior backend developer - Node.js / Python / AWS
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Analytics and Insights lead
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-noida-greater-noida-10-to-20-yrs-jobid-AqULIx3MBpJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Principal Architect ,  Advanced Engineering
# Company:  ICERTIS
# Skill:  security  ,  java  ,  multithreading  ,  c#  ,  python  ,  windows
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/principal-architect-advanced-engineering-icertis-20-to-23-yrs-jobid-YyCQroZkcUhzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Analytics and Insights lead
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-gurgaon-10-to-20-yrs-jobid-1ll4KhRbLqxzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Staff Engineer - Networking
# Company:  Cohesity
# Skill:  c    ,  linux  ,  python  ,  c  ,  linux networking  ,  sdn
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/staff-engineer-networking-cohesity-bengaluru-bangalore-10-to-20-yrs-jobid-jTvEwmtNdr5zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Lead Insights Analyst
# Company:  KVC CONSULTANTS LTD
# Skill:  sql  ,  mysql  ,  python  ,  machine learning  ,  web technologies
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/lead-insights-analyst-kvc-consultants-ltd-hyderabad-secunderabad-19-to-22-yrs-jobid-ySW72VwCdq9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud-Native Software Architect
# Company:  Parallel Wireless
# Skill:  c    ,  docker  ,  wireless communication  ,  linux  ,  telecom  ,  python  ,  mobile  ,  infrastructure  ,  nfv
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-native-software-architect-parallel-wireless-pune-bengaluru-bangalore-18-to-21-yrs-jobid-OZyUpGpd8j9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  VP ,  Data Science
# Company:  QUANTIUM SOLUTIONS
# Skill:  scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/vp-data-science-quantium-solutions-17-to-20-yrs-jobid-05hQkan__PLUS__0__SLASH__RzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  VP ,  Data Science
# Company:  Quantium Analytics
# Skill:  scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/vp-data-science-quantium-analytics-17-to-20-yrs-jobid-N5Cun1oPAWdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Development Master - Greenlake
# Company:  HP ENTERPRISE SERVICES
# Skill:  compilers  ,  devops  ,  debugging  ,  middleware  ,  python  ,  machine learning  ,  infrastructure  ,  forms
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-development-master-greenlake-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-sUYxHcpT__SLASH__qdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Application Solutions Evangelist
# Company:  CAREERXPERTS CONSULTING
# Skill:  python  ,  c    ,  solution architect  ,  java  ,  infrastructure  ,  cloud computing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-application-solutions-evangelist-careerxperts-consulting-hyderabad-secunderabad-gurgaon-mumbai-bengaluru-bangalore-8-to-20-yrs-jobid-MK73__SLASH____SLASH__f6cSVzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Data Scientist NLU /  NLP
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  python  ,  natural language processing  ,  machine learning  ,  artificial intelligence
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-data-scientist-nlu-nlp-analytics-vidhya-hyderabad-secunderabad-6-to-20-yrs-jobid-NraEhfjXXHdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technologies
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-j2mJL5zgdclzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technologies
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-aVGtebNAqNJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Architect
# Company:  Saama Technologies Pvt Ltd
# Skill:  security  ,  java  ,  iam  ,  software engineering  ,  cloud computing  ,  python  ,  infrastructure setup
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-architect-saama-technologies-pvt-ltd-pune-14-to-20-yrs-jobid-OorolNmxR3RzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technology India Pvt Ltd
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-1EBCP36v8dpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technology India Pvt Ltd
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-p07jucDKZ6lzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Operations Analyst I
# Company:  EagleView Technologies
# Skill:  bi  ,  sql  ,  salesforce  ,  database  ,  python  ,  problem solving  ,  machine learning  ,  imaging
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-operations-analyst-i-eagleview-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-3NeTcTiEzIJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Technical Architect and Product Owner  Data ,  Analytics and workload solutions
# Company:  HP ENTERPRISE SERVICES
# Skill:  orchestration  ,  database  ,  apache  ,  linux  ,  debugging  ,  hadoop  ,  python  ,  oracle  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/technical-architect-and-product-owner-data-analytics-and-workload-solutions-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-aetJkB2aZ5hzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Business Analyst
# Company:  AMAZON INDIA PVT LTD
# Skill:  hive  ,  bi  ,  data warehousing  ,  pig  ,  database  ,  hadoop  ,  big data  ,  hbase  ,  python  ,  written communication
# Posted Date:  Posted 5 days ago
# More info:  https://www.timesjobs.com/job-detail/business-analyst-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-BJuIqryOjNdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 5 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-gPu4O7VkkAZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-3qDX9dUc0hBzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-MpclfRtZ6fpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Data Architect
# Company:  Analytics Vidhya
# Skill:  java  ,  big data  ,  python  ,  cassandra  ,  hive  ,  data warehousing  ,  security  ,  database  ,  hadoop  ,  mongodb  ,  information management
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-data-architect-analytics-vidhya-bengaluru-bangalore-15-to-20-yrs-jobid-IKyhbbOHbkpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------

# %% [markdown]
# ## Jobs on All Pages

# %%
# fetch page number bar
bar = soup.find('div', class_='srp-pagination clearfix')
print(bar)
# Out:
# <div class="srp-pagination clearfix">
# <em class="active">1</em><em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em><em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em>
# </div>

# %%
# fetch sequences(page numbers and current page)
sequence = bar.find_all('em')
print(sequence)
for seq in sequence:
    print(seq)
# Out:
# [<em class="active">1</em>, <em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em>, <em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em>]
# <em class="active">1</em>
# <em><a href="#" onclick="getNextPageResult(2,1)" rel="next">2</a></em>
# <em><a href="#" onclick="getNextPageResult(3,1)" rel="next">3</a></em>

# %%
# find current page
print(bar.find('em', class_='active'))
# Out:
# <em class="active">1</em>

# %%
# find last page
print(sequence[-1].text)
# Out:
# 3

# %% [markdown]
# ### Start Code

# %%
# import modules
from bs4 import BeautifulSoup
import requests

# %%
base_url = 'https://www.timesjobs.com/'
my_job = input('Job: ')
experience = input("Enter only number.\nFor all experience, only press 'enter'.\nExperience: ")
# Out:
# Job: python
# Enter only number.
# For all experience, only press 'enter'.
# Experience: 20

# %%
seq = 1   # set page no

# fetch data until the last page
while True:

    # create url to fetch data on one page after another page 
    url = base_url + '/candidate/job-search.html?from=submit&txtKeywords=' + my_job+'&cboWorkExp1='+experience+'&sequence='+str(seq)

    # fetch HTMl text
    html_text = requests.get(url).text

    # parse HTML text using 'lxml'
    soup = BeautifulSoup(html_text, 'lxml')
    jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

    # loop all jobs and dispaly each job details.
    for job in jobs:

        # find required data in HTML tags
        position = job.find('h2').text.strip()
        print('Position: ', position)
        company_name = job.find('h3', class_='joblist-comp-name').text.strip()
        print('Company: ',company_name)
        skill = job.find('span', class_='srp-skills').text.strip()
        print('Skill: ',skill)
        published_date = job.find('span', class_='sim-posted').span.text.strip()
        print('Posted Date: ',published_date)
        more_info = job.header.h2.a['href']
        print('More info: ', more_info)
        print('-----------------------------------------------------------------------')

    # after one page, move to another page
    # check the page number bar and find current page
    bar = soup.find('div', class_='srp-pagination clearfix')
    # print(bar.find('em', class_='active').text)

    # get all  page numbers on the bar
    sequence_bar = bar.find_all('em')
    # print(sequence_bar[-1].text)

    # check the current page is the last page
    # print(bar.find('em', class_='active').text == sequence_bar[-1].text)

    # if current page is the last page, terminate loop.
    # else, move to another page and fetch data.
    if bar.find('em', class_='active').text == sequence_bar[-1].text:
        break
    seq = seq+1
# Out:
# Position:  Hiring Full stack developer - ReactJS / NodeJS / Python
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  information technology  ,  html5  ,  git  ,  html  ,  python  ,  mobile  ,  javascript  ,  node.js
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/hiring-full-stack-developer-reactjs-nodejs-python-glan-management-consultancy-pvt-ltd-mumbai-8-to-20-yrs-jobid-xywJrj4x6sVzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  senior backend developer - Node.js / Python / AWS
# Company:  glan management consultancy pvt. ltd.
# Skill:  css  ,  software design  ,  postgresql  ,  cake  ,  j2ee  ,  html  ,  mysql  ,  python  ,  javascript  ,  node.js  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-backend-developer-node-js-python-aws-glan-management-consultancy-pvt-ltd-mumbai-7-to-20-yrs-jobid-ZOII5LjoCUZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Analytics and Insights lead
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-noida-greater-noida-10-to-20-yrs-jobid-AqULIx3MBpJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Principal Architect ,  Advanced Engineering
# Company:  ICERTIS
# Skill:  security  ,  java  ,  multithreading  ,  c#  ,  python  ,  windows
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/principal-architect-advanced-engineering-icertis-20-to-23-yrs-jobid-YyCQroZkcUhzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Analytics and Insights lead
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  sql  ,  san  ,  python  ,  machine learning  ,  swing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-analytics-and-insights-lead-analytics-vidhya-gurgaon-10-to-20-yrs-jobid-1ll4KhRbLqxzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Staff Engineer - Networking
# Company:  Cohesity
# Skill:  c    ,  linux  ,  python  ,  c  ,  linux networking  ,  sdn
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/staff-engineer-networking-cohesity-bengaluru-bangalore-10-to-20-yrs-jobid-jTvEwmtNdr5zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Lead Insights Analyst
# Company:  KVC CONSULTANTS LTD
# Skill:  sql  ,  mysql  ,  python  ,  machine learning  ,  web technologies
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/lead-insights-analyst-kvc-consultants-ltd-hyderabad-secunderabad-19-to-22-yrs-jobid-ySW72VwCdq9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud-Native Software Architect
# Company:  Parallel Wireless
# Skill:  c    ,  docker  ,  wireless communication  ,  linux  ,  telecom  ,  python  ,  mobile  ,  infrastructure  ,  nfv
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-native-software-architect-parallel-wireless-pune-bengaluru-bangalore-18-to-21-yrs-jobid-OZyUpGpd8j9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  VP ,  Data Science
# Company:  QUANTIUM SOLUTIONS
# Skill:  scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/vp-data-science-quantium-solutions-17-to-20-yrs-jobid-05hQkan__PLUS__0__SLASH__RzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  VP ,  Data Science
# Company:  Quantium Analytics
# Skill:  scala  ,  artificial intelligence  ,  san  ,  rest  ,  python  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/vp-data-science-quantium-analytics-17-to-20-yrs-jobid-N5Cun1oPAWdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Development Master - Greenlake
# Company:  HP ENTERPRISE SERVICES
# Skill:  compilers  ,  devops  ,  debugging  ,  middleware  ,  python  ,  machine learning  ,  infrastructure  ,  forms
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-development-master-greenlake-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-sUYxHcpT__SLASH__qdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Application Solutions Evangelist
# Company:  CAREERXPERTS CONSULTING
# Skill:  python  ,  c    ,  solution architect  ,  java  ,  infrastructure  ,  cloud computing
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-application-solutions-evangelist-careerxperts-consulting-hyderabad-secunderabad-gurgaon-mumbai-bengaluru-bangalore-8-to-20-yrs-jobid-MK73__SLASH____SLASH__f6cSVzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Data Scientist NLU /  NLP
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  python  ,  natural language processing  ,  machine learning  ,  artificial intelligence
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-data-scientist-nlu-nlp-analytics-vidhya-hyderabad-secunderabad-6-to-20-yrs-jobid-NraEhfjXXHdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technologies
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-aVGtebNAqNJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technologies
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technologies-bengaluru-bangalore-12-to-20-yrs-jobid-j2mJL5zgdclzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Architect
# Company:  Saama Technologies Pvt Ltd
# Skill:  security  ,  java  ,  iam  ,  software engineering  ,  cloud computing  ,  python  ,  infrastructure setup
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-architect-saama-technologies-pvt-ltd-pune-14-to-20-yrs-jobid-OorolNmxR3RzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technology India Pvt Ltd
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-1EBCP36v8dpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior System Validation Engineer
# Company:  Intel Technology India Pvt Ltd
# Skill:  c    ,  storage  ,  artificial intelligence  ,  debugging  ,  perl  ,  python  ,  c
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-system-validation-engineer-intel-technology-india-pvt-ltd-bengaluru-bangalore-12-to-20-yrs-jobid-p07jucDKZ6lzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sales Operations Analyst I
# Company:  EagleView Technologies
# Skill:  bi  ,  sql  ,  salesforce  ,  database  ,  python  ,  problem solving  ,  machine learning  ,  imaging
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sales-operations-analyst-i-eagleview-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-3NeTcTiEzIJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Technical Architect and Product Owner  Data ,  Analytics and workload solutions
# Company:  HP ENTERPRISE SERVICES
# Skill:  orchestration  ,  database  ,  apache  ,  linux  ,  debugging  ,  hadoop  ,  python  ,  oracle  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/technical-architect-and-product-owner-data-analytics-and-workload-solutions-hp-enterprise-services-bengaluru-bangalore-15-to-20-yrs-jobid-aetJkB2aZ5hzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Business Analyst
# Company:  AMAZON INDIA PVT LTD
# Skill:  hive  ,  bi  ,  data warehousing  ,  pig  ,  database  ,  hadoop  ,  big data  ,  hbase  ,  python  ,  written communication
# Posted Date:  Posted 5 days ago
# More info:  https://www.timesjobs.com/job-detail/business-analyst-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-BJuIqryOjNdzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 5 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-gPu4O7VkkAZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-3qDX9dUc0hBzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer
# Company:  AMAZON INDIA PVT LTD
# Skill:  algorithms  ,  c    ,  database  ,  java  ,  linux  ,  data structures  ,  c#  ,  python  ,  c  ,  written communication  ,  unix
# Posted Date:  Posted 6 days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-MpclfRtZ6fpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Data Architect
# Company:  Analytics Vidhya
# Skill:  java  ,  big data  ,  python  ,  cassandra  ,  hive  ,  data warehousing  ,  security  ,  database  ,  hadoop  ,  mongodb  ,  information management
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-data-architect-analytics-vidhya-bengaluru-bangalore-15-to-20-yrs-jobid-IKyhbbOHbkpzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# 1
# 3
# False
# Position:  Solutions Architect- Cloud  ( Infra  &  Security )
# Company:  CloudThat Technologies
# Skill:  java  ,  devops  ,  technology consulting  ,  big data  ,  python  ,  oracle  ,  docker  ,  security  ,  cloud computing  ,  mongodb
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/solutions-architect-cloud-infra-security-cloudthat-technologies-mumbai-bengaluru-bangalore-17-to-20-yrs-jobid-pEqtz3vmR2NzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Subject Matter Expert - Infra  &  Security  ( Cloud )
# Company:  CloudThat Technologies
# Skill:  docker  ,  security  ,  java  ,  devops  ,  technology consulting  ,  big data  ,  cloud computing  ,  mongodb  ,  python  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/subject-matter-expert-infra-security-cloud-cloudthat-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-y8YvBtKVjThzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Principal RAN Engineer
# Company:  ACISION
# Skill:  3gpp  ,  oss  ,  umts  ,  python  ,  messaging  ,  network software  ,  bi  ,  sql  ,  telecom  ,  consultant  ,  fme
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/principal-ran-engineer-acision-20-to-23-yrs-jobid-LUOretdev7pzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Principal Data Scientist
# Company:  Analytics Vidhya
# Skill:  software design  ,  scala  ,  java  ,  apache  ,  hadoop  ,  big data  ,  python  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/principal-data-scientist-analytics-vidhya-bengaluru-bangalore-10-to-20-yrs-jobid-8oq8RyHcJ75zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Technical Architect
# Company:  FresherMart
# Skill:  c    ,  information technology  ,  sql  ,  security  ,  java  ,  uml  ,  python  ,  it skills  ,  team player  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/technical-architect-freshermart-mumbai-12-to-20-yrs-jobid-Oc2GK50C__SLASH__HZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  US Cyber Security Startup  Ground Floor
# Company:  CAREERXPERTS CONSULTING
# Skill:  algorithms  ,  c    ,  software design  ,  kernel programming  ,  security  ,  multithreading  ,  sockets  ,  python  ,  c  ,  windows  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/us-cyber-security-startup-ground-floor-careerxperts-consulting-bengaluru-bangalore-12-to-20-yrs-jobid-__PLUS__iiaTsMOSoFzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Data Science Product Manager
# Company:  SEVEN CONSULTANCY
# Skill:  c    ,  data warehousing  ,  sql  ,  java  ,  perl  ,  big data  ,  python  ,  c  ,  sas  ,  machine learning  ,  ruby  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/data-science-product-manager-seven-consultancy-hyderabad-secunderabad-15-to-20-yrs-jobid-M3NAK9n0f0BzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Manager ,  Security Architecture and Operations
# Company:  APPLYCUP HIRING SOLUTIONS LLP
# Skill:  pmp  ,  it governance  ,  python  ,  unix  ,  intrusion detection  ,  security  ,  linux  ,  perl  ,  c  ,  windows  ,  cism  ,  nist  ,  identity management  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/manager-security-architecture-and-operations-applycup-hiring-solutions-llp-pune-15-to-20-yrs-jobid-aqPeagofdXJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Machine Learning Engineer
# Company:  SEVEN CONSULTANCY
# Skill:  fundamentals  ,  algorithms  ,  artificial intelligence  ,  java  ,  data structures  ,  python  ,  natural language processing  ,  machine learning  ,  consultant
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/machine-learning-engineer-seven-consultancy-hyderabad-secunderabad-15-to-20-yrs-jobid-xJu2v9rsGApzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  AI Research Scientist
# Company:  SEVEN CONSULTANCY
# Skill:  c    ,  signal processing  ,  artificial intelligence  ,  java  ,  hadoop  ,  big data  ,  mongodb  ,  python  ,  machine learning  ,  consultant  ,  cassandra  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/ai-research-scientist-seven-consultancy-hyderabad-secunderabad-15-to-20-yrs-jobid-TK7GPOMk__SLASH__1tzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Data Scientist
# Company:  Analytics Vidhya
# Skill:  algorithms  ,  c    ,  sql  ,  fx  ,  c#  ,  python  ,  team player  ,  problem solving  ,  machine learning  ,  management systems
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-data-scientist-analytics-vidhya-noida-greater-noida-7-to-20-yrs-jobid-1BsIK__PLUS__I5RclzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sr Project Manager - Consulting
# Company:  blue yonder
# Skill:  pmp  ,  python  ,  oracle  ,  software implementation  ,  unix  ,  bi  ,  sql  ,  cloud services  ,  rdbms  ,  os  ,  problem solving  ,  windows  ,  project delivery
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sr-project-manager-consulting-blue-yonder-bengaluru-bangalore-15-to-20-yrs-jobid-DioVbLLffKVzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Research Associate- Cloud / IoT
# Company:  CloudThat Technologies
# Skill:  storage  ,  sql  ,  docker  ,  database  ,  security  ,  java  ,  postgresql  ,  devops  ,  big data  ,  cloud computing  ,  mongodb  ,  rest  ,  python  ,  cloud services  ,  oracle  ,  nosql
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/research-associate-cloud-iot-cloudthat-technologies-mumbai-bengaluru-bangalore-17-to-20-yrs-jobid-LxW83wCglKZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Director - Global Risk  &  Controls Technology
# Company:  Citibank India
# Skill:  java  ,  j2ee  ,  api  ,  big data  ,  python  ,  director  ,  web technologies  ,  sql  ,  security  ,  database  ,  hadoop  ,  rest  ,  c  ,  machine learning
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/director-global-risk-controls-technology-citibank-india-pune-20-to-23-yrs-jobid-pfjR8wYvr3NzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Software Development Engineer II
# Company:  AMAZON INDIA PVT LTD
# Skill:  c    ,  software design  ,  java  ,  api  ,  c#  ,  san  ,  python  ,  c  ,  machine learning  ,  javascript  ,  ruby  ,  android development  ,  written communication
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/software-development-engineer-ii-amazon-india-pvt-ltd-bengaluru-bangalore-20-to-23-yrs-jobid-DDGxQrmXSmxzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Data Science Director
# Company:  SEVEN CONSULTANCY
# Skill:  algorithms  ,  c    ,  data warehousing  ,  sql  ,  java  ,  perl  ,  big data  ,  rest  ,  python  ,  c  ,  natural language processing  ,  sas  ,  director  ,  machine learning  ,  ruby
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/data-science-director-seven-consultancy-hyderabad-secunderabad-15-to-20-yrs-jobid-dId__PLUS__xat8ST1zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Data Scientist
# Company:  SEVEN CONSULTANCY
# Skill:  algorithms  ,  c    ,  business rules  ,  data warehousing  ,  sql  ,  java  ,  perl  ,  big data  ,  python  ,  c  ,  sas  ,  machine learning  ,  ruby  ,  consultant
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/data-scientist-seven-consultancy-hyderabad-secunderabad-15-to-20-yrs-jobid-ATOIYfBrMOZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Senior Verification Methodology Engineer
# Company:  Advanced Micronic Devices Ltd
# Skill:  c    ,  graphics  ,  file system  ,  vhdl  ,  xml  ,  shell scripting  ,  multithreading  ,  python  ,  nosql  ,  unix  ,  sql  ,  git  ,  debugging  ,  json  ,  perl  ,  perforce  ,  c  ,  os  ,  ruby  ,  management systems
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/senior-verification-methodology-engineer-advanced-micronic-devices-ltd-hyderabad-secunderabad-12-to-20-yrs-jobid-FGOh16k1yydzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sr. Manager Data Science - Innovation  &  Architecture
# Company:  Lam Research
# Skill:  artificial intelligence  ,  java  ,  web api  ,  big data  ,  python  ,  .net  ,  hive  ,  algorithms  ,  technical leader  ,  bi  ,  hadoop  ,  technical skills  ,  business applications  ,  problem solving  ,  machine learning  ,  leadership skills
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sr-manager-data-science-innovation-architecture-lam-research-bengaluru-bangalore-6-to-20-yrs-jobid-oripZZVw7WxzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud / IoT - Subject Matter Expert
# Company:  CloudThat Technologies
# Skill:  storage  ,  sql  ,  docker  ,  security  ,  java  ,  devops  ,  technology consulting  ,  big data  ,  cloud computing  ,  mongodb  ,  python  ,  cloud services  ,  oracle  ,  problem solving  ,  nosql  ,  cassandra
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-iot-subject-matter-expert-cloudthat-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-cnKv4aCVQi9zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Sr. Staff  /  Principal Engineer  ( Architect )  - Saas API
# Company:  Netskope
# Skill:  information technology  ,  rest api  ,  salesforce  ,  api  ,  python  ,  messaging  ,  unix  ,  docker  ,  security  ,  linux  ,  cloud computing  ,  technical skills  ,  mongodb  ,  san  ,  cloud services  ,  software delivery  ,  problem solving
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/sr-staff-principal-engineer-architect-saas-api-netskope-bengaluru-bangalore-16-to-20-yrs-jobid-3Y__SLASH__orxawA5BzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Technical Lead
# Company:  Talent Corner Hr Services Private Limited
# Skill:  css  ,  html5  ,  bootstrap  ,  hibernate  ,  sso  ,  elastic search  ,  java  ,  testing tools  ,  enterprise java  ,  mysql  ,  api  ,  mongodb  ,  python  ,  oracle  ,  xamarin  ,  mobile  ,  django  ,  angularjs
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/technical-lead-talent-corner-hr-services-private-limited-chennai-17-to-20-yrs-jobid-XmOmq__PLUS__pwr9hzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Azure Solution Architect
# Company:  JobsLo Consultants
# Skill:  c    ,  java  ,  devops  ,  python  ,  javascript  ,  .net  ,  hosting  ,  bi  ,  sql  ,  security  ,  perl  ,  hadoop  ,  rest  ,  solution architect  ,  machine learning  ,  ruby  ,  neo4j  ,  infrastructure  ,  php  ,  service design
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/azure-solution-architect-jobslo-consultants-kanpur-16-to-20-yrs-jobid-xKGeHps3f3pzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Research Associate
# Company:  CloudThat Technologies
# Skill:  sql  ,  docker  ,  database  ,  security  ,  java  ,  postgresql  ,  devops  ,  linux  ,  big data  ,  cloud computing  ,  mongodb  ,  rest  ,  cloud services  ,  python  ,  oracle  ,  nosql  ,  infrastructure  ,  production environment
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/research-associate-cloudthat-technologies-mumbai-pune-bengaluru-bangalore-17-to-20-yrs-jobid-X2ocMkh9BcBzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Technical Trainer
# Company:  CloudThat Technologies
# Skill:  java  ,  devops  ,  technology consulting  ,  mysql  ,  web api  ,  big data  ,  c#  ,  python  ,  oracle  ,  node.js  ,  web technologies  ,  .net  ,  storage  ,  docker  ,  security  ,  git  ,  linux  ,  microsoft .net  ,  debugging  ,  mvc  ,  cloud computing  ,  mongodb  ,  svn  ,  windows
# Posted Date:  Posted 2 days ago
# More info:  https://www.timesjobs.com/job-detail/technical-trainer-cloudthat-technologies-bengaluru-bangalore-17-to-20-yrs-jobid-TG9LRpbiNitzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# 2
# 3
# False
# Position:  Lead Data Science Engineer
# Company:  SYSTEM SOFT INC.
# Skill:  pig  ,  java  ,  flume  ,  shell scripting  ,  api  ,  big data  ,  python  ,  impala  ,  nosql  ,  messaging  ,  mapreduce  ,  unix  ,  hive  ,  algorithms  ,  scala  ,  bi  ,  data warehousing  ,  sql  ,  database  ,  hadoop  ,  hbase  ,  natural language processing  ,  oozie  ,  information retrieval  ,  machine learning  ,  consultant  ,  hdfs  ,  sqoop  ,  forms
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/lead-data-science-engineer-system-soft-inc-hyderabad-secunderabad-20-to-23-yrs-jobid-yymrfwr__SLASH__VVBzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Associate Director - Cloud Architecture
# Company:  Larsen & Toubro Infotech Ltd
# Skill:  devops  ,  api  ,  windows azure  ,  vms  ,  python  ,  visual studio  ,  web technologies  ,  .net  ,  bi  ,  storage  ,  sql  ,  debugging  ,  mvc  ,  technical skills  ,  mobile  ,  microsoft azure  ,  problem solving  ,  machine learning  ,  identity management  ,  office automation
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/associate-director-cloud-architecture-larsen-toubro-infotech-ltd-bengaluru-bangalore-18-to-21-yrs-jobid-JxQPWn0I90NzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Supply Chain Technology Architect
# Company:  HP ENTERPRISE SERVICES
# Skill:  c    ,  css  ,  information technology  ,  java  ,  asp.net  ,  software engineering  ,  html  ,  big data  ,  c#  ,  python  ,  adapters  ,  web technologies  ,  hive  ,  fundamentals  ,  scala  ,  data warehousing  ,  sql  ,  json  ,  hadoop  ,  rest  ,  c  ,  written communication  ,  leadership skills
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/supply-chain-technology-architect-hp-enterprise-services-bengaluru-bangalore-14-to-20-yrs-jobid-gdXeKwfayJxzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Cloud Architect
# Company:  ABC Consultants Pvt Ltd
# Skill:  gcc  ,  java  ,  xml  ,  mqtt  ,  data structures  ,  mysql  ,  api  ,  python  ,  maven  ,  javascript  ,  eclipse  ,  computer graphics  ,  groovy  ,  clearcase  ,  soap  ,  udp  ,  scala  ,  hosting  ,  storage  ,  docker  ,  git  ,  json  ,  technical skills  ,  rest  ,  cloud services  ,  computer networks  ,  ant  ,  svn  ,  spring boot  ,  infrastructure  ,  gateway
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/cloud-architect-abc-consultants-pvt-ltd-bengaluru-bangalore-15-to-20-yrs-jobid-4FF2W4__SLASH__aUt5zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Enterprise Architect  ( Application )
# Company:  APPLYCUP HIRING SOLUTIONS LLP
# Skill:  c    ,  orchestration  ,  java  ,  apache  ,  devops  ,  software engineering  ,  data structures  ,  api  ,  c#  ,  python  ,  javascript  ,  messaging  ,  nosql  ,  cassandra  ,  web technologies  ,  algorithms  ,  scala  ,  software design  ,  linux  ,  hadoop  ,  mongodb  ,  hbase  ,  c  ,  windows  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/enterprise-architect-application-applycup-hiring-solutions-llp-chennai-12-to-22-yrs-jobid-MMmzE8ZMKkJzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Enterprise Architect  ( Application )
# Company:  APPLYCUP HIRING SOLUTIONS LLP
# Skill:  c    ,  orchestration  ,  java  ,  apache  ,  devops  ,  software engineering  ,  data structures  ,  api  ,  c#  ,  python  ,  javascript  ,  messaging  ,  nosql  ,  cassandra  ,  web technologies  ,  algorithms  ,  scala  ,  software design  ,  linux  ,  hadoop  ,  mongodb  ,  hbase  ,  c  ,  windows  ,  infrastructure
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/enterprise-architect-application-applycup-hiring-solutions-llp-hyderabad-secunderabad-12-to-22-yrs-jobid-Fsby9dj4HhFzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Leader - Data Science ,  Analytics  &  Reporting
# Company:  Golden Opportunities Pvt Ltd
# Skill:  advanced analytics  ,  visualization  ,  data analytics  ,  bi  ,  sql  ,  tableau  ,  data science
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/leader-data-science-analytics-reporting-golden-opportunities-pvt-ltd-bengaluru-bangalore-16-to-23-yrs-jobid-zvmUO1VVfRZzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Leader - Transformation Network
# Company:  Golden Opportunities Pvt Ltd
# Skill:  network engineering  ,  visualization  ,  consulting  ,  bi  ,  sql  ,  tableau  ,  data science  ,  telecom
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/leader-transformation-network-golden-opportunities-pvt-ltd-bengaluru-bangalore-16-to-20-yrs-jobid-D5wiT2ateJ1zpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Tech Manager  ( SaaS )
# Company:  CP Careers Pvt. Ltd.
#      (More Jobs)
# Skill:  Network Security  ,  Technical Product Manager  ,  Program management  ,  R & D  ,  reviews  ,  software components  ,   software design  ,  code  ,   Java  ,  Python  ,   SaaS  ,  microservice architecture
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail/tech-manager-saas-a-client-of-cpcareers-private-limited-bengaluru-bangalore-chennai-hyderabad-secunderabad-pune-15-to-20-yrs-jobid-ydTpZ2yO2__PLUS__lzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Azure Data Platform Practice Lead
# Company:  CP Careers Pvt. Ltd.
#      (More Jobs)
# Skill:  Azure Modern  ,  Data Platform  ,  Stakeholders  ,  designing  ,   architecting  ,   data processing  ,    ,  data storage  ,  data distribution systems  ,  Spark framework  ,  AWS  ,  Azure  ,  GCP
# Posted Date:  Posted few days ago
# More info:  https://www.timesjobs.com/job-detail/azure-data-platform-practice-lead-a-client-of-cpcareers-private-limited-bengaluru-bangalore-chennai-delhi-ncr-hyderabad-secunderabad-pune-15-to-20-yrs-jobid-z1iMaKsb56pzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# Position:  Data Solution Architect
# Company:  CP Careers Pvt. Ltd.
#      (More Jobs)
# Skill:  AWS  ,  Azure  ,  Design  ,  Data Solution  ,  Spark framework  ,  Data Bricks  ,  Snowflake  ,  Data Modelling  ,  Database Design  ,  DataWarehousing  ,  MPP  ,  Netezza  ,  Teradata  ,  Azure Synapse  ,  java
# Posted Date:  Posted a month ago
# More info:  https://www.timesjobs.com/job-detail/data-solution-architect-a-client-of-cpcareers-private-limited-bengaluru-bangalore-chennai-hyderabad-secunderabad-kolkata-noida-greater-noida-15-to-20-yrs-jobid-h__PLUS__bgUmh0CkFzpSvf__PLUS__uAgZw==&source=srp
# -----------------------------------------------------------------------
# 3
# 3
# True
